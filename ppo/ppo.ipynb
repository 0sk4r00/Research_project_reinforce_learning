# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical
from collections import deque
import csv

class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(ActorCritic, self).__init__()
        
        self.features = nn.Sequential(
            nn.Linear(state_dim, 512),
            nn.LayerNorm(512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.LayerNorm(512),
            nn.ReLU()
        )
        
        self.actor_features = nn.Sequential(
            nn.Linear(512, 256),
            nn.LayerNorm(256),
            nn.ReLU()
        )
        
        self.critic_features = nn.Sequential(
            nn.Linear(512, 256),
            nn.LayerNorm(256),
            nn.ReLU()
        )
        
        self.actor = nn.Sequential(
            nn.Linear(256, action_dim),
            nn.Softmax(dim=-1)
        )
        
        self.critic = nn.Linear(256, 1)
        
        self.apply(self._init_weights)
        
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight, gain=np.sqrt(2))
            module.bias.data.fill_(0.0)
        
    def forward(self, state):
        features = self.features(state)
        actor_feat = self.actor_features(features)
        critic_feat = self.critic_features(features)
        action_probs = self.actor(actor_feat)
        value = self.critic(critic_feat)
        return action_probs, value
    
    def get_action(self, state, deterministic=False):
        action_probs, value = self.forward(state)
        
        if deterministic:
            return torch.argmax(action_probs, dim=-1)
        
        dist = Categorical(action_probs)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        
        return action, log_prob, value

    def evaluate_actions(self, state, action):
        action_probs, value = self.forward(state)
        dist = Categorical(action_probs)
        log_prob = dist.log_prob(action)
        entropy = dist.entropy().mean()
        return log_prob, entropy, value

# %%
class PPO:
    def __init__(self, state_dim, action_dim):
        self.actor_critic = ActorCritic(state_dim, action_dim)
        self.optimizer = optim.Adam(self.actor_critic.parameters(), lr=1e-4, eps=1e-5)
        
        self.gamma = 0.99
        self.gae_lambda = 0.95
        self.clip_range = 0.2
        self.epochs = 4
        self.batch_size = 128
        
        self.vf_coef = 0.5
        self.ent_coef = 0.01
        self.max_grad_norm = 0.5
    
    def act(self, state, deterministic=False):
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            action = self.actor_critic.get_action(state_tensor, deterministic=deterministic)[0]
        return action.item()
        
    def update(self, rollouts):
        observations = torch.FloatTensor(rollouts['states'])
        actions = torch.LongTensor(rollouts['actions'])
        returns = torch.FloatTensor(rollouts['returns'])
        advantages = torch.FloatTensor(rollouts['advantages'])
        old_log_probs = torch.FloatTensor(rollouts['log_probs'])
        
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        
        for _ in range(self.epochs):
            indices = np.random.permutation(len(observations))
            
            for start in range(0, len(observations), self.batch_size):
                end = start + self.batch_size
                batch_indices = indices[start:end]
                
                obs_batch = observations[batch_indices]
                actions_batch = actions[batch_indices]
                returns_batch = returns[batch_indices]
                advantages_batch = advantages[batch_indices]
                old_log_probs_batch = old_log_probs[batch_indices]
                
                new_log_probs, entropy, values = self.actor_critic.evaluate_actions(
                    obs_batch, actions_batch
                )
                
                ratio = torch.exp(new_log_probs - old_log_probs_batch)
                surr1 = ratio * advantages_batch
                surr2 = torch.clamp(ratio, 1.0 - self.clip_range, 1.0 + self.clip_range) * advantages_batch
                
                policy_loss = -torch.min(surr1, surr2).mean()
                value_loss = self.vf_coef * ((values.squeeze() - returns_batch) ** 2).mean()
                entropy_loss = -self.ent_coef * entropy
                
                total_loss = policy_loss + value_loss + entropy_loss
                
                self.optimizer.zero_grad()
                total_loss.backward()
                nn.utils.clip_grad_norm_(self.actor_critic.parameters(), self.max_grad_norm)
                self.optimizer.step()

    def save(self, path):
        torch.save(self.actor_critic.state_dict(), path)
    
    def load(self, path):
        self.actor_critic.load_state_dict(torch.load(path))

# %%
def compute_returns_and_advantages(rewards, values, next_value, dones, gamma=0.99, gae_lambda=0.95):
    advantages = []
    last_advantage = 0
    last_value = next_value

    for r, v, done in zip(reversed(rewards), reversed(values), reversed(dones)):
        delta = r + gamma * last_value * (1 - done) - v
        advantage = delta + gamma * gae_lambda * (1 - done) * last_advantage
        advantages.insert(0, advantage)
        last_advantage = advantage
        last_value = v

    returns = np.array(advantages) + np.array(values)
    advantages = np.array(advantages)
    
    return returns, advantages

def evaluate(agent, env, num_episodes=100, max_steps=1000):
    all_rewards = []
    all_steps = []
    
    # Create evaluation CSV file
    with open('evaluation_results.csv', 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Episode', 'Reward', 'Steps'])
    
    for i_episode in range(num_episodes):
        state, _ = env.reset()
        episode_reward = 0
        
        for step in range(max_steps):
            action = agent.act(state, deterministic=True)  # Use deterministic actions for evaluation
            next_state, reward, terminated, truncated, _ = env.step(action)
            episode_reward += reward
            
            if terminated or truncated:
                break
            state = next_state
        
        all_rewards.append(episode_reward)
        all_steps.append(step + 1)
        
        # Save episode results
        with open('evaluation_results.csv', 'a', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow([i_episode + 1, episode_reward, step + 1])
    
    avg_reward = np.mean(all_rewards)
    avg_steps = np.mean(all_steps)
    std_reward = np.std(all_rewards)
    
    print(f"\nEvaluation over {num_episodes} episodes:")
    print(f"Average Reward: {avg_reward:.2f} ± {std_reward:.2f}")
    print(f"Average Episode Length: {avg_steps:.2f}")
    
    return avg_reward, avg_steps

# %%
def train():
    # Create CSV file for training progress
    with open('lunar_lander_rewards.csv', 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Episode', 'Reward', 'Mean_100'])
    
    env = gym.make('LunarLander-v3')
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n
    
    ppo = PPO(state_dim, action_dim)
    
    timesteps_per_batch = 4096
    num_episodes = 3000  # Fixed number of episodes
    best_mean_reward = -float('inf')
    
    recent_rewards = deque(maxlen=100)
    episode_num = 0
    
    while episode_num < num_episodes:
        states, actions, rewards, dones, log_probs, values = [], [], [], [], [], []
        batch_steps = 0
        
        while batch_steps < timesteps_per_batch and episode_num < num_episodes:
            state, _ = env.reset()
            episode_reward = 0
            done = False
            
            while not done and batch_steps < timesteps_per_batch:
                state_tensor = torch.FloatTensor(state).unsqueeze(0)
                
                with torch.no_grad():
                    action, log_prob, value = ppo.actor_critic.get_action(state_tensor)
                
                next_state, reward, terminated, truncated, _ = env.step(action.item())
                done = terminated or truncated
                
                states.append(state)
                actions.append(action.item())
                rewards.append(reward)
                dones.append(done)
                log_probs.append(log_prob.item())
                values.append(value.item())
                
                state = next_state
                episode_reward += reward
                batch_steps += 1
            
            episode_num += 1
            recent_rewards.append(episode_reward)
            mean_reward = np.mean(recent_rewards)
            
            # Print and save episode results
            print(f"Episode {episode_num}: Reward = {episode_reward:.2f}, Mean (100) = {mean_reward:.2f}")
            
            with open('lunar_lander_rewards.csv', 'a', newline='') as csvfile:
                writer = csv.writer(csvfile)
                writer.writerow([episode_num, episode_reward, mean_reward])
            
            if mean_reward > best_mean_reward and len(recent_rewards) == 100:
                best_mean_reward = mean_reward
                ppo.save('best_lunar_model.pt')
                print(f"New best model saved with mean reward: {best_mean_reward:.2f}")
        
        with torch.no_grad():
            next_value = ppo.actor_critic(
                torch.FloatTensor(next_state).unsqueeze(0)
            )[1].item()
            
        returns, advantages = compute_returns_and_advantages(
            rewards, values, next_value, dones,
            gamma=ppo.gamma, gae_lambda=ppo.gae_lambda
        )
        
        rollouts = {
            'states': np.array(states),
            'actions': np.array(actions),
            'returns': returns,
            'advantages': advantages,
            'log_probs': np.array(log_probs)
        }
        
        ppo.update(rollouts)
    
    # Save final model
    ppo.save('final_lunar_model.pt')
    print("Training completed. Final model saved.")
    
    # Load best model and evaluate
    print("\nEvaluating best model...")
    ppo.load('best_lunar_model.pt')
    evaluate(ppo, env)
    
    env.close()

# %%
if __name__ == "__main__":
    train()
# Out:
# Episode 1: Reward = -304.75, Mean (100) = -304.75
# Episode 2: Reward = -208.65, Mean (100) = -256.70
# Episode 3: Reward = -375.62, Mean (100) = -296.34
# Episode 4: Reward = -464.66, Mean (100) = -338.42
# Episode 5: Reward = -309.05, Mean (100) = -332.55
# Episode 6: Reward = -318.25, Mean (100) = -330.16
# Episode 7: Reward = -329.54, Mean (100) = -330.07
# Episode 8: Reward = -292.66, Mean (100) = -325.40
# Episode 9: Reward = -316.92, Mean (100) = -324.45
# Episode 10: Reward = -457.69, Mean (100) = -337.78
# Episode 11: Reward = -424.70, Mean (100) = -345.68
# Episode 12: Reward = -559.22, Mean (100) = -363.48
# Episode 13: Reward = -216.38, Mean (100) = -352.16
# Episode 14: Reward = -459.50, Mean (100) = -359.83
# Episode 15: Reward = -265.16, Mean (100) = -353.52
# Episode 16: Reward = -569.20, Mean (100) = -367.00
# Episode 17: Reward = -515.33, Mean (100) = -375.72
# Episode 18: Reward = -452.66, Mean (100) = -380.00
# Episode 19: Reward = -206.64, Mean (100) = -370.87
# Episode 20: Reward = -547.07, Mean (100) = -379.68
# Episode 21: Reward = -522.06, Mean (100) = -386.46
# Episode 22: Reward = -490.89, Mean (100) = -391.21
# Episode 23: Reward = -319.83, Mean (100) = -388.11
# Episode 24: Reward = -507.57, Mean (100) = -393.08
# Episode 25: Reward = -465.01, Mean (100) = -395.96
# Episode 26: Reward = -322.84, Mean (100) = -393.15
# Episode 27: Reward = -314.58, Mean (100) = -390.24
# Episode 28: Reward = -508.84, Mean (100) = -394.47
# Episode 29: Reward = -602.72, Mean (100) = -401.65
# Episode 30: Reward = -248.04, Mean (100) = -396.53
# Episode 31: Reward = -398.64, Mean (100) = -396.60
# Episode 32: Reward = -419.50, Mean (100) = -397.32
# Episode 33: Reward = -394.54, Mean (100) = -397.23
# Episode 34: Reward = -355.07, Mean (100) = -395.99
# Episode 35: Reward = -483.80, Mean (100) = -398.50
# Episode 36: Reward = -475.69, Mean (100) = -400.65
# Episode 37: Reward = -416.94, Mean (100) = -401.09
# Episode 38: Reward = -383.97, Mean (100) = -400.64
# Episode 39: Reward = -467.18, Mean (100) = -402.34
# Episode 40: Reward = -327.70, Mean (100) = -400.48
# Episode 41: Reward = -318.33, Mean (100) = -398.47
# Episode 42: Reward = -263.58, Mean (100) = -395.26
# Episode 43: Reward = -284.56, Mean (100) = -392.69
# Episode 44: Reward = -490.15, Mean (100) = -394.90
# Episode 45: Reward = -282.08, Mean (100) = -392.39
# Episode 46: Reward = -444.69, Mean (100) = -393.53
# Episode 47: Reward = -359.17, Mean (100) = -392.80
# Episode 48: Reward = -334.84, Mean (100) = -391.59
# Episode 49: Reward = -436.19, Mean (100) = -392.50
# Episode 50: Reward = -471.69, Mean (100) = -394.09
# Episode 51: Reward = -558.18, Mean (100) = -397.30
# Episode 52: Reward = -482.37, Mean (100) = -398.94
# Episode 53: Reward = -523.72, Mean (100) = -401.29
# Episode 54: Reward = -6.38, Mean (100) = -393.98
# Episode 55: Reward = -319.41, Mean (100) = -392.63
# Episode 56: Reward = -479.43, Mean (100) = -394.18
# Episode 57: Reward = -420.26, Mean (100) = -394.63
# Episode 58: Reward = -519.55, Mean (100) = -396.79
# Episode 59: Reward = -602.04, Mean (100) = -400.27
# Episode 60: Reward = -413.59, Mean (100) = -400.49
# Episode 61: Reward = -302.51, Mean (100) = -398.88
# Episode 62: Reward = -299.22, Mean (100) = -397.27
# Episode 63: Reward = -395.92, Mean (100) = -397.25
# Episode 64: Reward = -352.20, Mean (100) = -396.55
# Episode 65: Reward = -430.33, Mean (100) = -397.07
# Episode 66: Reward = -284.68, Mean (100) = -395.37
# Episode 67: Reward = -479.72, Mean (100) = -396.62
# Episode 68: Reward = -492.64, Mean (100) = -398.04
# Episode 69: Reward = -459.99, Mean (100) = -398.93
# Episode 70: Reward = -370.79, Mean (100) = -398.53
# Episode 71: Reward = -303.34, Mean (100) = -397.19
# Episode 72: Reward = -431.93, Mean (100) = -397.67
# Episode 73: Reward = -427.84, Mean (100) = -398.09
# Episode 74: Reward = -307.45, Mean (100) = -396.86
# Episode 75: Reward = -555.45, Mean (100) = -398.98
# Episode 76: Reward = -299.19, Mean (100) = -397.66
# Episode 77: Reward = -404.74, Mean (100) = -397.76
# Episode 78: Reward = -429.56, Mean (100) = -398.16
# Episode 79: Reward = -361.36, Mean (100) = -397.70
# Episode 80: Reward = -464.93, Mean (100) = -398.54
# Episode 81: Reward = -356.02, Mean (100) = -398.01
# Episode 82: Reward = -343.00, Mean (100) = -397.34
# Episode 83: Reward = -426.32, Mean (100) = -397.69
# Episode 84: Reward = -364.44, Mean (100) = -397.30
# Episode 85: Reward = -478.60, Mean (100) = -398.25
# Episode 86: Reward = -461.88, Mean (100) = -398.99
# Episode 87: Reward = -419.53, Mean (100) = -399.23
# Episode 88: Reward = -291.00, Mean (100) = -398.00
# Episode 89: Reward = -327.15, Mean (100) = -397.20
# Episode 90: Reward = -322.00, Mean (100) = -396.37
# Episode 91: Reward = -260.89, Mean (100) = -394.88
# Episode 92: Reward = -329.84, Mean (100) = -394.17
# Episode 93: Reward = -394.00, Mean (100) = -394.17
# Episode 94: Reward = -405.06, Mean (100) = -394.28
# Episode 95: Reward = -510.98, Mean (100) = -395.51
# Episode 96: Reward = -262.99, Mean (100) = -394.13
# Episode 97: Reward = -299.08, Mean (100) = -393.15
# Episode 98: Reward = -442.31, Mean (100) = -393.65
# Episode 99: Reward = -411.14, Mean (100) = -393.83
# Episode 100: Reward = -356.25, Mean (100) = -393.46
# New best model saved with mean reward: -393.46
# Episode 101: Reward = -266.00, Mean (100) = -393.07
# New best model saved with mean reward: -393.07
# Episode 102: Reward = -455.77, Mean (100) = -395.54
# Episode 103: Reward = -464.70, Mean (100) = -396.43
# Episode 104: Reward = -2.81, Mean (100) = -391.81
# New best model saved with mean reward: -391.81
# Episode 105: Reward = -296.78, Mean (100) = -391.69
# New best model saved with mean reward: -391.69
# Episode 106: Reward = -359.78, Mean (100) = -392.10
# Episode 107: Reward = -261.11, Mean (100) = -391.42
# New best model saved with mean reward: -391.42
# Episode 108: Reward = -431.35, Mean (100) = -392.81
# Episode 109: Reward = -410.32, Mean (100) = -393.74
# Episode 110: Reward = -384.84, Mean (100) = -393.01
# Episode 111: Reward = -459.16, Mean (100) = -393.36
# Episode 112: Reward = -280.82, Mean (100) = -390.57
# New best model saved with mean reward: -390.57
# Episode 113: Reward = -211.20, Mean (100) = -390.52
# New best model saved with mean reward: -390.52
# Episode 114: Reward = -575.11, Mean (100) = -391.68
# Episode 115: Reward = -389.53, Mean (100) = -392.92
# Episode 116: Reward = -337.75, Mean (100) = -390.61
# Episode 117: Reward = -249.48, Mean (100) = -387.95
# New best model saved with mean reward: -387.95
# Episode 118: Reward = -306.40, Mean (100) = -386.49
# New best model saved with mean reward: -386.49
# Episode 119: Reward = -322.99, Mean (100) = -387.65
# Episode 120: Reward = -211.59, Mean (100) = -384.29
# New best model saved with mean reward: -384.29
# Episode 121: Reward = -246.58, Mean (100) = -381.54
# New best model saved with mean reward: -381.54
# Episode 122: Reward = -278.44, Mean (100) = -379.41
# New best model saved with mean reward: -379.41
# Episode 123: Reward = -359.84, Mean (100) = -379.81
# Episode 124: Reward = -197.71, Mean (100) = -376.72
# New best model saved with mean reward: -376.72
# Episode 125: Reward = -402.39, Mean (100) = -376.09
# New best model saved with mean reward: -376.09
# Episode 126: Reward = -218.79, Mean (100) = -375.05
# New best model saved with mean reward: -375.05
# Episode 127: Reward = -454.70, Mean (100) = -376.45
# Episode 128: Reward = -279.53, Mean (100) = -374.16
# New best model saved with mean reward: -374.16
# Episode 129: Reward = -287.54, Mean (100) = -371.01
# New best model saved with mean reward: -371.01
# Episode 130: Reward = -295.04, Mean (100) = -371.48
# Episode 131: Reward = -360.65, Mean (100) = -371.10
# Episode 132: Reward = -363.55, Mean (100) = -370.54
# New best model saved with mean reward: -370.54
# Episode 133: Reward = -263.32, Mean (100) = -369.22
# New best model saved with mean reward: -369.22
# Episode 134: Reward = -444.07, Mean (100) = -370.11
# Episode 135: Reward = -406.27, Mean (100) = -369.34
# Episode 136: Reward = -314.88, Mean (100) = -367.73
# New best model saved with mean reward: -367.73
# Episode 137: Reward = -367.06, Mean (100) = -367.23
# New best model saved with mean reward: -367.23
# Episode 138: Reward = -287.11, Mean (100) = -366.26
# New best model saved with mean reward: -366.26
# Episode 139: Reward = -427.78, Mean (100) = -365.87
# New best model saved with mean reward: -365.87
# Episode 140: Reward = -279.75, Mean (100) = -365.39
# New best model saved with mean reward: -365.39
# Episode 141: Reward = -129.96, Mean (100) = -363.51
# New best model saved with mean reward: -363.51
# Episode 142: Reward = -295.52, Mean (100) = -363.83
# Episode 143: Reward = -287.29, Mean (100) = -363.85
# Episode 144: Reward = -206.21, Mean (100) = -361.01
# New best model saved with mean reward: -361.01
# Episode 145: Reward = -406.68, Mean (100) = -362.26
# Episode 146: Reward = -309.46, Mean (100) = -360.91
# New best model saved with mean reward: -360.91
# Episode 147: Reward = -276.58, Mean (100) = -360.08
# New best model saved with mean reward: -360.08
# Episode 148: Reward = -170.46, Mean (100) = -358.44
# New best model saved with mean reward: -358.44
# Episode 149: Reward = -350.70, Mean (100) = -357.58
# New best model saved with mean reward: -357.58
# Episode 150: Reward = -55.92, Mean (100) = -353.42
# New best model saved with mean reward: -353.42
# Episode 151: Reward = -267.79, Mean (100) = -350.52
# New best model saved with mean reward: -350.52
# Episode 152: Reward = -297.05, Mean (100) = -348.67
# New best model saved with mean reward: -348.67
# Episode 153: Reward = -308.43, Mean (100) = -346.51
# New best model saved with mean reward: -346.51
# Episode 154: Reward = -251.58, Mean (100) = -348.97
# Episode 155: Reward = -476.87, Mean (100) = -350.54
# Episode 156: Reward = -59.56, Mean (100) = -346.34
# New best model saved with mean reward: -346.34
# Episode 157: Reward = -286.71, Mean (100) = -345.01
# New best model saved with mean reward: -345.01
# Episode 158: Reward = -348.81, Mean (100) = -343.30
# New best model saved with mean reward: -343.30
# Episode 159: Reward = -226.75, Mean (100) = -339.55
# New best model saved with mean reward: -339.55
# Episode 160: Reward = -390.16, Mean (100) = -339.31
# New best model saved with mean reward: -339.31
# Episode 161: Reward = -349.18, Mean (100) = -339.78
# Episode 162: Reward = -314.41, Mean (100) = -339.93
# Episode 163: Reward = -269.60, Mean (100) = -338.67
# New best model saved with mean reward: -338.67
# Episode 164: Reward = -251.13, Mean (100) = -337.66
# New best model saved with mean reward: -337.66
# Episode 165: Reward = -329.96, Mean (100) = -336.65
# New best model saved with mean reward: -336.65
# Episode 166: Reward = -252.34, Mean (100) = -336.33
# New best model saved with mean reward: -336.33
# Episode 167: Reward = -212.90, Mean (100) = -333.66
# New best model saved with mean reward: -333.66
# Episode 168: Reward = -272.41, Mean (100) = -331.46
# New best model saved with mean reward: -331.46
# Episode 169: Reward = -311.71, Mean (100) = -329.98
# New best model saved with mean reward: -329.98
# Episode 170: Reward = -24.57, Mean (100) = -326.51
# New best model saved with mean reward: -326.51
# Episode 171: Reward = -328.91, Mean (100) = -326.77
# Episode 172: Reward = -373.86, Mean (100) = -326.19
# New best model saved with mean reward: -326.19
# Episode 173: Reward = -248.26, Mean (100) = -324.39
# New best model saved with mean reward: -324.39
# Episode 174: Reward = -189.28, Mean (100) = -323.21
# New best model saved with mean reward: -323.21
# Episode 175: Reward = -45.33, Mean (100) = -318.11
# New best model saved with mean reward: -318.11
# Episode 176: Reward = -406.59, Mean (100) = -319.18
# Episode 177: Reward = -208.13, Mean (100) = -317.22
# New best model saved with mean reward: -317.22
# Episode 178: Reward = -374.75, Mean (100) = -316.67
# New best model saved with mean reward: -316.67
# Episode 179: Reward = -254.81, Mean (100) = -315.60
# New best model saved with mean reward: -315.60
# Episode 180: Reward = -460.22, Mean (100) = -315.56
# New best model saved with mean reward: -315.56
# Episode 181: Reward = -238.09, Mean (100) = -314.38
# New best model saved with mean reward: -314.38
# Episode 182: Reward = -264.38, Mean (100) = -313.59
# New best model saved with mean reward: -313.59
# Episode 183: Reward = -373.37, Mean (100) = -313.06
# New best model saved with mean reward: -313.06
# Episode 184: Reward = -313.59, Mean (100) = -312.55
# New best model saved with mean reward: -312.55
# Episode 185: Reward = -290.23, Mean (100) = -310.67
# New best model saved with mean reward: -310.67
# Episode 186: Reward = -341.04, Mean (100) = -309.46
# New best model saved with mean reward: -309.46
# Episode 187: Reward = -346.53, Mean (100) = -308.73
# New best model saved with mean reward: -308.73
# Episode 188: Reward = -350.82, Mean (100) = -309.33
# Episode 189: Reward = -268.84, Mean (100) = -308.75
# Episode 190: Reward = -338.66, Mean (100) = -308.91
# Episode 191: Reward = -233.64, Mean (100) = -308.64
# New best model saved with mean reward: -308.64
# Episode 192: Reward = -313.55, Mean (100) = -308.48
# New best model saved with mean reward: -308.48
# Episode 193: Reward = -154.18, Mean (100) = -306.08
# New best model saved with mean reward: -306.08
# Episode 194: Reward = -150.02, Mean (100) = -303.53
# New best model saved with mean reward: -303.53
# Episode 195: Reward = -362.66, Mean (100) = -302.05
# New best model saved with mean reward: -302.05
# Episode 196: Reward = -344.81, Mean (100) = -302.87
# Episode 197: Reward = -304.52, Mean (100) = -302.92
# Episode 198: Reward = -225.85, Mean (100) = -300.75
# New best model saved with mean reward: -300.75
# Episode 199: Reward = -206.55, Mean (100) = -298.71
# New best model saved with mean reward: -298.71
# Episode 200: Reward = -208.26, Mean (100) = -297.23
# New best model saved with mean reward: -297.23
# Episode 201: Reward = -457.80, Mean (100) = -299.15
# Episode 202: Reward = -382.75, Mean (100) = -298.42
# Episode 203: Reward = -59.36, Mean (100) = -294.36
# New best model saved with mean reward: -294.36
# Episode 204: Reward = -159.97, Mean (100) = -295.94
# Episode 205: Reward = -165.15, Mean (100) = -294.62
# Episode 206: Reward = -272.30, Mean (100) = -293.74
# New best model saved with mean reward: -293.74
# Episode 207: Reward = -110.58, Mean (100) = -292.24
# New best model saved with mean reward: -292.24
# Episode 208: Reward = -280.32, Mean (100) = -290.73
# New best model saved with mean reward: -290.73
# Episode 209: Reward = -84.06, Mean (100) = -287.47
# New best model saved with mean reward: -287.47
# Episode 210: Reward = -246.56, Mean (100) = -286.08
# New best model saved with mean reward: -286.08
# Episode 211: Reward = -57.24, Mean (100) = -282.06
# New best model saved with mean reward: -282.06
# Episode 212: Reward = -314.02, Mean (100) = -282.40
# Episode 213: Reward = -244.44, Mean (100) = -282.73
# Episode 214: Reward = -73.78, Mean (100) = -277.71
# New best model saved with mean reward: -277.71
# Episode 215: Reward = -184.31, Mean (100) = -275.66
# New best model saved with mean reward: -275.66
# Episode 216: Reward = -371.09, Mean (100) = -276.00
# Episode 217: Reward = -308.66, Mean (100) = -276.59
# Episode 218: Reward = -129.09, Mean (100) = -274.81
# New best model saved with mean reward: -274.81
# Episode 219: Reward = -382.46, Mean (100) = -275.41
# Episode 220: Reward = -190.71, Mean (100) = -275.20
# Episode 221: Reward = -228.70, Mean (100) = -275.02
# Episode 222: Reward = -395.69, Mean (100) = -276.19
# Episode 223: Reward = -114.03, Mean (100) = -273.74
# New best model saved with mean reward: -273.74
# Episode 224: Reward = -290.78, Mean (100) = -274.67
# Episode 225: Reward = -165.87, Mean (100) = -272.30
# New best model saved with mean reward: -272.30
# Episode 226: Reward = -317.59, Mean (100) = -273.29
# Episode 227: Reward = -159.00, Mean (100) = -270.33
# New best model saved with mean reward: -270.33
# Episode 228: Reward = -245.41, Mean (100) = -269.99
# New best model saved with mean reward: -269.99
# Episode 229: Reward = -253.08, Mean (100) = -269.65
# New best model saved with mean reward: -269.65
# Episode 230: Reward = -182.98, Mean (100) = -268.53
# New best model saved with mean reward: -268.53
# Episode 231: Reward = -152.56, Mean (100) = -266.45
# New best model saved with mean reward: -266.45
# Episode 232: Reward = -161.83, Mean (100) = -264.43
# New best model saved with mean reward: -264.43
# Episode 233: Reward = -260.15, Mean (100) = -264.40
# New best model saved with mean reward: -264.40
# Episode 234: Reward = -313.22, Mean (100) = -263.09
# New best model saved with mean reward: -263.09
# Episode 235: Reward = -347.90, Mean (100) = -262.50
# New best model saved with mean reward: -262.50
# Episode 236: Reward = -311.15, Mean (100) = -262.47
# New best model saved with mean reward: -262.47
# Episode 237: Reward = -373.84, Mean (100) = -262.54
# Episode 238: Reward = -342.49, Mean (100) = -263.09
# Episode 239: Reward = -360.12, Mean (100) = -262.41
# New best model saved with mean reward: -262.41
# Episode 240: Reward = -326.22, Mean (100) = -262.88
# Episode 241: Reward = -117.50, Mean (100) = -262.75
# Episode 242: Reward = -176.80, Mean (100) = -261.57
# New best model saved with mean reward: -261.57
# Episode 243: Reward = -37.39, Mean (100) = -259.07
# New best model saved with mean reward: -259.07
# Episode 244: Reward = -125.33, Mean (100) = -258.26
# New best model saved with mean reward: -258.26
# Episode 245: Reward = -22.66, Mean (100) = -254.42
# New best model saved with mean reward: -254.42
# Episode 246: Reward = -68.36, Mean (100) = -252.01
# New best model saved with mean reward: -252.01
# Episode 247: Reward = -93.72, Mean (100) = -250.18
# New best model saved with mean reward: -250.18
# Episode 248: Reward = -268.87, Mean (100) = -251.16
# Episode 249: Reward = -6.89, Mean (100) = -247.72
# New best model saved with mean reward: -247.72
# Episode 250: Reward = -356.14, Mean (100) = -250.73
# Episode 251: Reward = -80.57, Mean (100) = -248.85
# Episode 252: Reward = -93.56, Mean (100) = -246.82
# New best model saved with mean reward: -246.82
# Episode 253: Reward = -89.44, Mean (100) = -244.63
# New best model saved with mean reward: -244.63
# Episode 254: Reward = -110.79, Mean (100) = -243.22
# New best model saved with mean reward: -243.22
# Episode 255: Reward = -123.13, Mean (100) = -239.68
# New best model saved with mean reward: -239.68
# Episode 256: Reward = -71.38, Mean (100) = -239.80
# Episode 257: Reward = -246.58, Mean (100) = -239.40
# New best model saved with mean reward: -239.40
# Episode 258: Reward = -262.75, Mean (100) = -238.54
# New best model saved with mean reward: -238.54
# Episode 259: Reward = -57.11, Mean (100) = -236.84
# New best model saved with mean reward: -236.84
# Episode 260: Reward = -64.58, Mean (100) = -233.59
# New best model saved with mean reward: -233.59
# Episode 261: Reward = -230.90, Mean (100) = -232.40
# New best model saved with mean reward: -232.40
# Episode 262: Reward = -112.78, Mean (100) = -230.39
# New best model saved with mean reward: -230.39
# Episode 263: Reward = -257.18, Mean (100) = -230.26
# New best model saved with mean reward: -230.26
# Episode 264: Reward = -88.92, Mean (100) = -228.64
# New best model saved with mean reward: -228.64
# Episode 265: Reward = -181.54, Mean (100) = -227.16
# New best model saved with mean reward: -227.16
# Episode 266: Reward = -172.87, Mean (100) = -226.36
# New best model saved with mean reward: -226.36
# Episode 267: Reward = -200.93, Mean (100) = -226.24
# New best model saved with mean reward: -226.24
# Episode 268: Reward = -213.54, Mean (100) = -225.66
# New best model saved with mean reward: -225.66
# Episode 269: Reward = -105.15, Mean (100) = -223.59
# New best model saved with mean reward: -223.59
# Episode 270: Reward = -91.44, Mean (100) = -224.26
# Episode 271: Reward = -58.60, Mean (100) = -221.56
# New best model saved with mean reward: -221.56
# Episode 272: Reward = -110.27, Mean (100) = -218.92
# New best model saved with mean reward: -218.92
# Episode 273: Reward = -98.17, Mean (100) = -217.42
# New best model saved with mean reward: -217.42
# Episode 274: Reward = -308.48, Mean (100) = -218.61
# Episode 275: Reward = -81.88, Mean (100) = -218.98
# Episode 276: Reward = -122.95, Mean (100) = -216.14
# New best model saved with mean reward: -216.14
# Episode 277: Reward = -110.87, Mean (100) = -215.17
# New best model saved with mean reward: -215.17
# Episode 278: Reward = -70.24, Mean (100) = -212.12
# New best model saved with mean reward: -212.12
# Episode 279: Reward = -50.22, Mean (100) = -210.08
# New best model saved with mean reward: -210.08
# Episode 280: Reward = -225.19, Mean (100) = -207.73
# New best model saved with mean reward: -207.73
# Episode 281: Reward = -194.04, Mean (100) = -207.28
# New best model saved with mean reward: -207.28
# Episode 282: Reward = -95.43, Mean (100) = -205.60
# New best model saved with mean reward: -205.60
# Episode 283: Reward = -187.60, Mean (100) = -203.74
# New best model saved with mean reward: -203.74
# Episode 284: Reward = -78.34, Mean (100) = -201.39
# New best model saved with mean reward: -201.39
# Episode 285: Reward = -72.46, Mean (100) = -199.21
# New best model saved with mean reward: -199.21
# Episode 286: Reward = -96.63, Mean (100) = -196.76
# New best model saved with mean reward: -196.76
# Episode 287: Reward = -84.44, Mean (100) = -194.14
# New best model saved with mean reward: -194.14
# Episode 288: Reward = -89.61, Mean (100) = -191.53
# New best model saved with mean reward: -191.53
# Episode 289: Reward = -220.29, Mean (100) = -191.04
# New best model saved with mean reward: -191.04
# Episode 290: Reward = -25.58, Mean (100) = -187.91
# New best model saved with mean reward: -187.91
# Episode 291: Reward = -70.34, Mean (100) = -186.28
# New best model saved with mean reward: -186.28
# Episode 292: Reward = -195.30, Mean (100) = -185.10
# New best model saved with mean reward: -185.10
# Episode 293: Reward = -254.79, Mean (100) = -186.10
# Episode 294: Reward = -98.09, Mean (100) = -185.59
# Episode 295: Reward = -61.53, Mean (100) = -182.57
# New best model saved with mean reward: -182.57
# Episode 296: Reward = -101.90, Mean (100) = -180.15
# New best model saved with mean reward: -180.15
# Episode 297: Reward = -285.33, Mean (100) = -179.95
# New best model saved with mean reward: -179.95
# Episode 298: Reward = -115.07, Mean (100) = -178.85
# New best model saved with mean reward: -178.85
# Episode 299: Reward = -266.08, Mean (100) = -179.44
# Episode 300: Reward = -180.54, Mean (100) = -179.16
# Episode 301: Reward = -118.50, Mean (100) = -175.77
# New best model saved with mean reward: -175.77
# Episode 302: Reward = -175.89, Mean (100) = -173.70
# New best model saved with mean reward: -173.70
# Episode 303: Reward = -163.48, Mean (100) = -174.74
# Episode 304: Reward = 6.59, Mean (100) = -173.08
# New best model saved with mean reward: -173.08
# Episode 305: Reward = -140.05, Mean (100) = -172.83
# New best model saved with mean reward: -172.83
# Episode 306: Reward = -81.11, Mean (100) = -170.91
# New best model saved with mean reward: -170.91
# Episode 307: Reward = -105.38, Mean (100) = -170.86
# New best model saved with mean reward: -170.86
# Episode 308: Reward = -64.43, Mean (100) = -168.70
# New best model saved with mean reward: -168.70
# Episode 309: Reward = -121.29, Mean (100) = -169.08
# Episode 310: Reward = -56.26, Mean (100) = -167.17
# New best model saved with mean reward: -167.17
# Episode 311: Reward = -165.51, Mean (100) = -168.26
# Episode 312: Reward = -173.09, Mean (100) = -166.85
# New best model saved with mean reward: -166.85
# Episode 313: Reward = -121.19, Mean (100) = -165.61
# New best model saved with mean reward: -165.61
# Episode 314: Reward = -142.80, Mean (100) = -166.30
# Episode 315: Reward = -114.39, Mean (100) = -165.60
# New best model saved with mean reward: -165.60
# Episode 316: Reward = -336.55, Mean (100) = -165.26
# New best model saved with mean reward: -165.26
# Episode 317: Reward = -114.63, Mean (100) = -163.32
# New best model saved with mean reward: -163.32
# Episode 318: Reward = -114.88, Mean (100) = -163.18
# New best model saved with mean reward: -163.18
# Episode 319: Reward = -131.37, Mean (100) = -160.67
# New best model saved with mean reward: -160.67
# Episode 320: Reward = -105.64, Mean (100) = -159.82
# New best model saved with mean reward: -159.82
# Episode 321: Reward = -63.81, Mean (100) = -158.17
# New best model saved with mean reward: -158.17
# Episode 322: Reward = -161.11, Mean (100) = -155.82
# New best model saved with mean reward: -155.82
# Episode 323: Reward = -65.48, Mean (100) = -155.33
# New best model saved with mean reward: -155.33
# Episode 324: Reward = -101.66, Mean (100) = -153.44
# New best model saved with mean reward: -153.44
# Episode 325: Reward = -83.65, Mean (100) = -152.62
# New best model saved with mean reward: -152.62
# Episode 326: Reward = -103.83, Mean (100) = -150.48
# New best model saved with mean reward: -150.48
# Episode 327: Reward = -92.34, Mean (100) = -149.82
# New best model saved with mean reward: -149.82
# Episode 328: Reward = -61.93, Mean (100) = -147.98
# New best model saved with mean reward: -147.98
# Episode 329: Reward = -76.23, Mean (100) = -146.21
# New best model saved with mean reward: -146.21
# Episode 330: Reward = -141.24, Mean (100) = -145.80
# New best model saved with mean reward: -145.80
# Episode 331: Reward = -6.08, Mean (100) = -144.33
# New best model saved with mean reward: -144.33
# Episode 332: Reward = -74.79, Mean (100) = -143.46
# New best model saved with mean reward: -143.46
# Episode 333: Reward = -119.93, Mean (100) = -142.06
# New best model saved with mean reward: -142.06
# Episode 334: Reward = -136.94, Mean (100) = -140.30
# New best model saved with mean reward: -140.30
# Episode 335: Reward = -55.38, Mean (100) = -137.37
# New best model saved with mean reward: -137.37
# Episode 336: Reward = -185.08, Mean (100) = -136.11
# New best model saved with mean reward: -136.11
# Episode 337: Reward = -73.88, Mean (100) = -133.11
# New best model saved with mean reward: -133.11
# Episode 338: Reward = -129.09, Mean (100) = -130.98
# New best model saved with mean reward: -130.98
# Episode 339: Reward = -96.87, Mean (100) = -128.34
# New best model saved with mean reward: -128.34
# Episode 340: Reward = -130.45, Mean (100) = -126.39
# New best model saved with mean reward: -126.39
# Episode 341: Reward = -106.61, Mean (100) = -126.28
# New best model saved with mean reward: -126.28
# Episode 342: Reward = -141.90, Mean (100) = -125.93
# New best model saved with mean reward: -125.93
# Episode 343: Reward = -312.78, Mean (100) = -128.68
# Episode 344: Reward = -101.18, Mean (100) = -128.44
# Episode 345: Reward = -115.33, Mean (100) = -129.37
# Episode 346: Reward = -99.01, Mean (100) = -129.67
# Episode 347: Reward = -100.23, Mean (100) = -129.74
# Episode 348: Reward = -136.55, Mean (100) = -128.42
# Episode 349: Reward = -80.38, Mean (100) = -129.15
# Episode 350: Reward = -236.15, Mean (100) = -127.95
# Episode 351: Reward = -128.41, Mean (100) = -128.43
# Episode 352: Reward = -166.15, Mean (100) = -129.16
# Episode 353: Reward = -79.93, Mean (100) = -129.06
# Episode 354: Reward = -186.80, Mean (100) = -129.82
# Episode 355: Reward = -65.12, Mean (100) = -129.24
# Episode 356: Reward = -52.18, Mean (100) = -129.05
# Episode 357: Reward = -176.60, Mean (100) = -128.35
# Episode 358: Reward = -128.20, Mean (100) = -127.00
# Episode 359: Reward = -43.61, Mean (100) = -126.87
# Episode 360: Reward = -163.96, Mean (100) = -127.86
# Episode 361: Reward = -99.42, Mean (100) = -126.55
# Episode 362: Reward = -91.77, Mean (100) = -126.34
# Episode 363: Reward = -34.58, Mean (100) = -124.11
# New best model saved with mean reward: -124.11
# Episode 364: Reward = -112.57, Mean (100) = -124.35
# Episode 365: Reward = -182.20, Mean (100) = -124.35
# Episode 366: Reward = -64.46, Mean (100) = -123.27
# New best model saved with mean reward: -123.27
# Episode 367: Reward = -127.81, Mean (100) = -122.54
# New best model saved with mean reward: -122.54
# Episode 368: Reward = -112.49, Mean (100) = -121.53
# New best model saved with mean reward: -121.53
# Episode 369: Reward = -49.12, Mean (100) = -120.97
# New best model saved with mean reward: -120.97
# Episode 370: Reward = -89.87, Mean (100) = -120.95
# New best model saved with mean reward: -120.95
# Episode 371: Reward = -238.39, Mean (100) = -122.75
# Episode 372: Reward = -116.69, Mean (100) = -122.81
# Episode 373: Reward = -152.07, Mean (100) = -123.35
# Episode 374: Reward = -219.20, Mean (100) = -122.46
# Episode 375: Reward = 30.76, Mean (100) = -121.33
# Episode 376: Reward = -119.77, Mean (100) = -121.30
# Episode 377: Reward = -72.49, Mean (100) = -120.92
# New best model saved with mean reward: -120.92
# Episode 378: Reward = -55.27, Mean (100) = -120.77
# New best model saved with mean reward: -120.77
# Episode 379: Reward = -86.18, Mean (100) = -121.13
# Episode 380: Reward = -98.52, Mean (100) = -119.86
# New best model saved with mean reward: -119.86
# Episode 381: Reward = -136.95, Mean (100) = -119.29
# New best model saved with mean reward: -119.29
# Episode 382: Reward = -124.34, Mean (100) = -119.58
# Episode 383: Reward = -259.61, Mean (100) = -120.30
# Episode 384: Reward = -36.08, Mean (100) = -119.88
# Episode 385: Reward = -214.51, Mean (100) = -121.30
# Episode 386: Reward = -72.84, Mean (100) = -121.06
# Episode 387: Reward = -63.36, Mean (100) = -120.85
# Episode 388: Reward = -146.85, Mean (100) = -121.42
# Episode 389: Reward = -43.56, Mean (100) = -119.65
# Episode 390: Reward = -59.51, Mean (100) = -119.99
# Episode 391: Reward = -95.15, Mean (100) = -120.24
# Episode 392: Reward = -77.58, Mean (100) = -119.06
# New best model saved with mean reward: -119.06
# Episode 393: Reward = -27.78, Mean (100) = -116.79
# New best model saved with mean reward: -116.79
# Episode 394: Reward = -112.09, Mean (100) = -116.93
# Episode 395: Reward = -125.34, Mean (100) = -117.57
# Episode 396: Reward = -64.63, Mean (100) = -117.20
# Episode 397: Reward = -149.09, Mean (100) = -115.84
# New best model saved with mean reward: -115.84
# Episode 398: Reward = -95.21, Mean (100) = -115.64
# New best model saved with mean reward: -115.64
# Episode 399: Reward = -74.33, Mean (100) = -113.72
# New best model saved with mean reward: -113.72
# Episode 400: Reward = -141.16, Mean (100) = -113.33
# New best model saved with mean reward: -113.33
# Episode 401: Reward = -137.31, Mean (100) = -113.52
# Episode 402: Reward = -318.26, Mean (100) = -114.94
# Episode 403: Reward = -73.23, Mean (100) = -114.04
# Episode 404: Reward = -40.01, Mean (100) = -114.50
# Episode 405: Reward = -53.46, Mean (100) = -113.64
# Episode 406: Reward = -170.47, Mean (100) = -114.53
# Episode 407: Reward = -66.38, Mean (100) = -114.14
# Episode 408: Reward = -89.58, Mean (100) = -114.39
# Episode 409: Reward = -63.71, Mean (100) = -113.82
# Episode 410: Reward = -97.54, Mean (100) = -114.23
# Episode 411: Reward = -52.29, Mean (100) = -113.10
# New best model saved with mean reward: -113.10
# Episode 412: Reward = -87.76, Mean (100) = -112.24
# New best model saved with mean reward: -112.24
# Episode 413: Reward = 29.61, Mean (100) = -110.74
# New best model saved with mean reward: -110.74
# Episode 414: Reward = -128.08, Mean (100) = -110.59
# New best model saved with mean reward: -110.59
# Episode 415: Reward = -106.87, Mean (100) = -110.51
# New best model saved with mean reward: -110.51
# Episode 416: Reward = -56.93, Mean (100) = -107.72
# New best model saved with mean reward: -107.72
# Episode 417: Reward = -35.30, Mean (100) = -106.92
# New best model saved with mean reward: -106.92
# Episode 418: Reward = -53.27, Mean (100) = -106.31
# New best model saved with mean reward: -106.31
# Episode 419: Reward = -120.76, Mean (100) = -106.20
# New best model saved with mean reward: -106.20
# Episode 420: Reward = -73.41, Mean (100) = -105.88
# New best model saved with mean reward: -105.88
# Episode 421: Reward = -64.25, Mean (100) = -105.88
# Episode 422: Reward = -61.66, Mean (100) = -104.89
# New best model saved with mean reward: -104.89
# Episode 423: Reward = -72.21, Mean (100) = -104.96
# Episode 424: Reward = -51.31, Mean (100) = -104.45
# New best model saved with mean reward: -104.45
# Episode 425: Reward = -42.71, Mean (100) = -104.04
# New best model saved with mean reward: -104.04
# Episode 426: Reward = -99.39, Mean (100) = -104.00
# New best model saved with mean reward: -104.00
# Episode 427: Reward = -117.50, Mean (100) = -104.25
# Episode 428: Reward = -49.92, Mean (100) = -104.13
# Episode 429: Reward = -181.66, Mean (100) = -105.19
# Episode 430: Reward = -40.90, Mean (100) = -104.18
# Episode 431: Reward = -72.40, Mean (100) = -104.84
# Episode 432: Reward = -85.86, Mean (100) = -104.96
# Episode 433: Reward = -56.39, Mean (100) = -104.32
# Episode 434: Reward = -42.32, Mean (100) = -103.37
# New best model saved with mean reward: -103.37
# Episode 435: Reward = -84.08, Mean (100) = -103.66
# Episode 436: Reward = -3.15, Mean (100) = -101.84
# New best model saved with mean reward: -101.84
# Episode 437: Reward = -77.42, Mean (100) = -101.88
# Episode 438: Reward = -26.74, Mean (100) = -100.85
# New best model saved with mean reward: -100.85
# Episode 439: Reward = -41.07, Mean (100) = -100.30
# New best model saved with mean reward: -100.30
# Episode 440: Reward = -95.51, Mean (100) = -99.95
# New best model saved with mean reward: -99.95
# Episode 441: Reward = -37.03, Mean (100) = -99.25
# New best model saved with mean reward: -99.25
# Episode 442: Reward = -66.17, Mean (100) = -98.49
# New best model saved with mean reward: -98.49
# Episode 443: Reward = -48.26, Mean (100) = -95.85
# New best model saved with mean reward: -95.85
# Episode 444: Reward = -57.41, Mean (100) = -95.41
# New best model saved with mean reward: -95.41
# Episode 445: Reward = -49.36, Mean (100) = -94.75
# New best model saved with mean reward: -94.75
# Episode 446: Reward = -43.64, Mean (100) = -94.20
# New best model saved with mean reward: -94.20
# Episode 447: Reward = 70.04, Mean (100) = -92.49
# New best model saved with mean reward: -92.49
# Episode 448: Reward = -147.40, Mean (100) = -92.60
# Episode 449: Reward = -48.16, Mean (100) = -92.28
# New best model saved with mean reward: -92.28
# Episode 450: Reward = -10.05, Mean (100) = -90.02
# New best model saved with mean reward: -90.02
# Episode 451: Reward = -89.77, Mean (100) = -89.63
# New best model saved with mean reward: -89.63
# Episode 452: Reward = -52.28, Mean (100) = -88.49
# New best model saved with mean reward: -88.49
# Episode 453: Reward = -29.04, Mean (100) = -87.99
# New best model saved with mean reward: -87.99
# Episode 454: Reward = -61.71, Mean (100) = -86.73
# New best model saved with mean reward: -86.73
# Episode 455: Reward = -43.81, Mean (100) = -86.52
# New best model saved with mean reward: -86.52
# Episode 456: Reward = -60.30, Mean (100) = -86.60
# Episode 457: Reward = -19.87, Mean (100) = -85.04
# New best model saved with mean reward: -85.04
# Episode 458: Reward = -0.57, Mean (100) = -83.76
# New best model saved with mean reward: -83.76
# Episode 459: Reward = -99.03, Mean (100) = -84.31
# Episode 460: Reward = -63.80, Mean (100) = -83.31
# New best model saved with mean reward: -83.31
# Episode 461: Reward = -47.28, Mean (100) = -82.79
# New best model saved with mean reward: -82.79
# Episode 462: Reward = -97.10, Mean (100) = -82.84
# Episode 463: Reward = -85.40, Mean (100) = -83.35
# Episode 464: Reward = -93.70, Mean (100) = -83.16
# Episode 465: Reward = -83.69, Mean (100) = -82.18
# New best model saved with mean reward: -82.18
# Episode 466: Reward = -52.91, Mean (100) = -82.06
# New best model saved with mean reward: -82.06
# Episode 467: Reward = -31.76, Mean (100) = -81.10
# New best model saved with mean reward: -81.10
# Episode 468: Reward = -78.36, Mean (100) = -80.76
# New best model saved with mean reward: -80.76
# Episode 469: Reward = -68.85, Mean (100) = -80.96
# Episode 470: Reward = -82.01, Mean (100) = -80.88
# Episode 471: Reward = -45.82, Mean (100) = -78.95
# New best model saved with mean reward: -78.95
# Episode 472: Reward = -55.72, Mean (100) = -78.34
# New best model saved with mean reward: -78.34
# Episode 473: Reward = -55.16, Mean (100) = -77.38
# New best model saved with mean reward: -77.38
# Episode 474: Reward = -41.45, Mean (100) = -75.60
# New best model saved with mean reward: -75.60
# Episode 475: Reward = -124.64, Mean (100) = -77.15
# Episode 476: Reward = -48.93, Mean (100) = -76.44
# Episode 477: Reward = -39.42, Mean (100) = -76.11
# Episode 478: Reward = -59.58, Mean (100) = -76.16
# Episode 479: Reward = -5.87, Mean (100) = -75.35
# New best model saved with mean reward: -75.35
# Episode 480: Reward = -8.79, Mean (100) = -74.46
# New best model saved with mean reward: -74.46
# Episode 481: Reward = -28.45, Mean (100) = -73.37
# New best model saved with mean reward: -73.37
# Episode 482: Reward = -149.28, Mean (100) = -73.62
# Episode 483: Reward = -73.01, Mean (100) = -71.75
# New best model saved with mean reward: -71.75
# Episode 484: Reward = -42.54, Mean (100) = -71.82
# Episode 485: Reward = -53.47, Mean (100) = -70.21
# New best model saved with mean reward: -70.21
# Episode 486: Reward = -54.74, Mean (100) = -70.03
# New best model saved with mean reward: -70.03
# Episode 487: Reward = -20.23, Mean (100) = -69.60
# New best model saved with mean reward: -69.60
# Episode 488: Reward = 3.28, Mean (100) = -68.09
# New best model saved with mean reward: -68.09
# Episode 489: Reward = -48.56, Mean (100) = -68.14
# Episode 490: Reward = -69.64, Mean (100) = -68.25
# Episode 491: Reward = -25.10, Mean (100) = -67.55
# New best model saved with mean reward: -67.55
# Episode 492: Reward = -68.89, Mean (100) = -67.46
# New best model saved with mean reward: -67.46
# Episode 493: Reward = -68.80, Mean (100) = -67.87
# Episode 494: Reward = -21.24, Mean (100) = -66.96
# New best model saved with mean reward: -66.96
# Episode 495: Reward = -17.75, Mean (100) = -65.88
# New best model saved with mean reward: -65.88
# Episode 496: Reward = -43.95, Mean (100) = -65.68
# New best model saved with mean reward: -65.68
# Episode 497: Reward = -13.39, Mean (100) = -64.32
# New best model saved with mean reward: -64.32
# Episode 498: Reward = 22.49, Mean (100) = -63.14
# New best model saved with mean reward: -63.14
# Episode 499: Reward = 9.91, Mean (100) = -62.30
# New best model saved with mean reward: -62.30
# Episode 500: Reward = -21.85, Mean (100) = -61.11
# New best model saved with mean reward: -61.11
# Episode 501: Reward = -12.22, Mean (100) = -59.86
# New best model saved with mean reward: -59.86
# Episode 502: Reward = -38.78, Mean (100) = -57.06
# New best model saved with mean reward: -57.06
# Episode 503: Reward = 22.51, Mean (100) = -56.11
# New best model saved with mean reward: -56.11
# Episode 504: Reward = -6.19, Mean (100) = -55.77
# New best model saved with mean reward: -55.77
# Episode 505: Reward = -2.02, Mean (100) = -55.25
# New best model saved with mean reward: -55.25
# Episode 506: Reward = -72.47, Mean (100) = -54.27
# New best model saved with mean reward: -54.27
# Episode 507: Reward = 3.38, Mean (100) = -53.57
# New best model saved with mean reward: -53.57
# Episode 508: Reward = -19.26, Mean (100) = -52.87
# New best model saved with mean reward: -52.87
# Episode 509: Reward = -40.71, Mean (100) = -52.64
# New best model saved with mean reward: -52.64
# Episode 510: Reward = -28.06, Mean (100) = -51.95
# New best model saved with mean reward: -51.95
# Episode 511: Reward = -54.77, Mean (100) = -51.97
# Episode 512: Reward = -0.64, Mean (100) = -51.10
# New best model saved with mean reward: -51.10
# Episode 513: Reward = -41.55, Mean (100) = -51.81
# Episode 514: Reward = -55.40, Mean (100) = -51.09
# New best model saved with mean reward: -51.09
# Episode 515: Reward = -26.97, Mean (100) = -50.29
# New best model saved with mean reward: -50.29
# Episode 516: Reward = -24.70, Mean (100) = -49.96
# New best model saved with mean reward: -49.96
# Episode 517: Reward = -35.11, Mean (100) = -49.96
# New best model saved with mean reward: -49.96
# Episode 518: Reward = -2.96, Mean (100) = -49.46
# New best model saved with mean reward: -49.46
# Episode 519: Reward = 25.29, Mean (100) = -48.00
# New best model saved with mean reward: -48.00
# Episode 520: Reward = 12.21, Mean (100) = -47.14
# New best model saved with mean reward: -47.14
# Episode 521: Reward = -53.07, Mean (100) = -47.03
# New best model saved with mean reward: -47.03
# Episode 522: Reward = -26.58, Mean (100) = -46.68
# New best model saved with mean reward: -46.68
# Episode 523: Reward = 14.34, Mean (100) = -45.81
# New best model saved with mean reward: -45.81
# Episode 524: Reward = -113.62, Mean (100) = -46.44
# Episode 525: Reward = 22.95, Mean (100) = -45.78
# New best model saved with mean reward: -45.78
# Episode 526: Reward = -74.72, Mean (100) = -45.53
# New best model saved with mean reward: -45.53
# Episode 527: Reward = -29.33, Mean (100) = -44.65
# New best model saved with mean reward: -44.65
# Episode 528: Reward = -24.46, Mean (100) = -44.40
# New best model saved with mean reward: -44.40
# Episode 529: Reward = -63.01, Mean (100) = -43.21
# New best model saved with mean reward: -43.21
# Episode 530: Reward = -51.51, Mean (100) = -43.32
# Episode 531: Reward = -40.46, Mean (100) = -43.00
# New best model saved with mean reward: -43.00
# Episode 532: Reward = -41.45, Mean (100) = -42.55
# New best model saved with mean reward: -42.55
# Episode 533: Reward = 16.51, Mean (100) = -41.82
# New best model saved with mean reward: -41.82
# Episode 534: Reward = -3.12, Mean (100) = -41.43
# New best model saved with mean reward: -41.43
# Episode 535: Reward = -50.66, Mean (100) = -41.10
# New best model saved with mean reward: -41.10
# Episode 536: Reward = -11.72, Mean (100) = -41.18
# Episode 537: Reward = -86.88, Mean (100) = -41.28
# Episode 538: Reward = -19.32, Mean (100) = -41.20
# Episode 539: Reward = -54.82, Mean (100) = -41.34
# Episode 540: Reward = 77.46, Mean (100) = -39.61
# New best model saved with mean reward: -39.61
# Episode 541: Reward = -39.23, Mean (100) = -39.63
# Episode 542: Reward = -85.29, Mean (100) = -39.83
# Episode 543: Reward = 41.18, Mean (100) = -38.93
# New best model saved with mean reward: -38.93
# Episode 544: Reward = 117.64, Mean (100) = -37.18
# New best model saved with mean reward: -37.18
# Episode 545: Reward = 24.63, Mean (100) = -36.44
# New best model saved with mean reward: -36.44
# Episode 546: Reward = 18.89, Mean (100) = -35.82
# New best model saved with mean reward: -35.82
# Episode 547: Reward = -77.88, Mean (100) = -37.29
# Episode 548: Reward = -13.73, Mean (100) = -35.96
# Episode 549: Reward = -19.88, Mean (100) = -35.68
# New best model saved with mean reward: -35.68
# Episode 550: Reward = 55.28, Mean (100) = -35.02
# New best model saved with mean reward: -35.02
# Episode 551: Reward = -44.76, Mean (100) = -34.57
# New best model saved with mean reward: -34.57
# Episode 552: Reward = -41.53, Mean (100) = -34.46
# New best model saved with mean reward: -34.46
# Episode 553: Reward = -4.69, Mean (100) = -34.22
# New best model saved with mean reward: -34.22
# Episode 554: Reward = -24.61, Mean (100) = -33.85
# New best model saved with mean reward: -33.85
# Episode 555: Reward = -45.87, Mean (100) = -33.87
# Episode 556: Reward = -82.02, Mean (100) = -34.09
# Episode 557: Reward = 46.18, Mean (100) = -33.43
# New best model saved with mean reward: -33.43
# Episode 558: Reward = 2.39, Mean (100) = -33.40
# New best model saved with mean reward: -33.40
# Episode 559: Reward = 22.84, Mean (100) = -32.18
# New best model saved with mean reward: -32.18
# Episode 560: Reward = -32.39, Mean (100) = -31.86
# New best model saved with mean reward: -31.86
# Episode 561: Reward = -53.34, Mean (100) = -31.93
# Episode 562: Reward = 8.56, Mean (100) = -30.87
# New best model saved with mean reward: -30.87
# Episode 563: Reward = -6.70, Mean (100) = -30.08
# New best model saved with mean reward: -30.08
# Episode 564: Reward = -1.75, Mean (100) = -29.16
# New best model saved with mean reward: -29.16
# Episode 565: Reward = -77.23, Mean (100) = -29.10
# New best model saved with mean reward: -29.10
# Episode 566: Reward = 6.28, Mean (100) = -28.51
# New best model saved with mean reward: -28.51
# Episode 567: Reward = -46.79, Mean (100) = -28.66
# Episode 568: Reward = -9.21, Mean (100) = -27.96
# New best model saved with mean reward: -27.96
# Episode 569: Reward = -70.53, Mean (100) = -27.98
# Episode 570: Reward = -3.32, Mean (100) = -27.19
# New best model saved with mean reward: -27.19
# Episode 571: Reward = 113.00, Mean (100) = -25.61
# New best model saved with mean reward: -25.61
# Episode 572: Reward = -57.15, Mean (100) = -25.62
# Episode 573: Reward = 65.35, Mean (100) = -24.42
# New best model saved with mean reward: -24.42
# Episode 574: Reward = -56.43, Mean (100) = -24.57
# Episode 575: Reward = -37.93, Mean (100) = -23.70
# New best model saved with mean reward: -23.70
# Episode 576: Reward = -50.52, Mean (100) = -23.71
# Episode 577: Reward = -3.02, Mean (100) = -23.35
# New best model saved with mean reward: -23.35
# Episode 578: Reward = 2.02, Mean (100) = -22.73
# New best model saved with mean reward: -22.73
# Episode 579: Reward = -69.67, Mean (100) = -23.37
# Episode 580: Reward = -70.38, Mean (100) = -23.99
# Episode 581: Reward = -39.60, Mean (100) = -24.10
# Episode 582: Reward = 15.85, Mean (100) = -22.45
# New best model saved with mean reward: -22.45
# Episode 583: Reward = 150.11, Mean (100) = -20.22
# New best model saved with mean reward: -20.22
# Episode 584: Reward = -25.09, Mean (100) = -20.04
# New best model saved with mean reward: -20.04
# Episode 585: Reward = 36.31, Mean (100) = -19.14
# New best model saved with mean reward: -19.14
# Episode 586: Reward = 42.45, Mean (100) = -18.17
# New best model saved with mean reward: -18.17
# Episode 587: Reward = 12.35, Mean (100) = -17.85
# New best model saved with mean reward: -17.85
# Episode 588: Reward = -60.37, Mean (100) = -18.48
# Episode 589: Reward = -7.88, Mean (100) = -18.08
# Episode 590: Reward = -9.10, Mean (100) = -17.47
# New best model saved with mean reward: -17.47
# Episode 591: Reward = 83.59, Mean (100) = -16.38
# New best model saved with mean reward: -16.38
# Episode 592: Reward = 0.59, Mean (100) = -15.69
# New best model saved with mean reward: -15.69
# Episode 593: Reward = 82.03, Mean (100) = -14.18
# New best model saved with mean reward: -14.18
# Episode 594: Reward = 36.28, Mean (100) = -13.61
# New best model saved with mean reward: -13.61
# Episode 595: Reward = 41.58, Mean (100) = -13.01
# New best model saved with mean reward: -13.01
# Episode 596: Reward = -102.34, Mean (100) = -13.60
# Episode 597: Reward = 42.06, Mean (100) = -13.04
# Episode 598: Reward = 30.09, Mean (100) = -12.97
# New best model saved with mean reward: -12.97
# Episode 599: Reward = -37.61, Mean (100) = -13.44
# Episode 600: Reward = 60.07, Mean (100) = -12.62
# New best model saved with mean reward: -12.62
# Episode 601: Reward = 55.32, Mean (100) = -11.95
# New best model saved with mean reward: -11.95
# Episode 602: Reward = 32.68, Mean (100) = -11.23
# New best model saved with mean reward: -11.23
# Episode 603: Reward = 5.17, Mean (100) = -11.41
# Episode 604: Reward = -4.00, Mean (100) = -11.38
# Episode 605: Reward = -49.00, Mean (100) = -11.85
# Episode 606: Reward = 121.62, Mean (100) = -9.91
# New best model saved with mean reward: -9.91
# Episode 607: Reward = -1.99, Mean (100) = -9.97
# Episode 608: Reward = -81.41, Mean (100) = -10.59
# Episode 609: Reward = -10.68, Mean (100) = -10.29
# Episode 610: Reward = -31.74, Mean (100) = -10.32
# Episode 611: Reward = -25.38, Mean (100) = -10.03
# Episode 612: Reward = -54.43, Mean (100) = -10.57
# Episode 613: Reward = -24.83, Mean (100) = -10.40
# Episode 614: Reward = -9.25, Mean (100) = -9.94
# Episode 615: Reward = -76.91, Mean (100) = -10.44
# Episode 616: Reward = 41.85, Mean (100) = -9.77
# New best model saved with mean reward: -9.77
# Episode 617: Reward = 84.49, Mean (100) = -8.58
# New best model saved with mean reward: -8.58
# Episode 618: Reward = 8.25, Mean (100) = -8.47
# New best model saved with mean reward: -8.47
# Episode 619: Reward = -60.51, Mean (100) = -9.32
# Episode 620: Reward = -35.62, Mean (100) = -9.80
# Episode 621: Reward = -28.63, Mean (100) = -9.56
# Episode 622: Reward = -10.20, Mean (100) = -9.39
# Episode 623: Reward = -51.69, Mean (100) = -10.05
# Episode 624: Reward = -9.52, Mean (100) = -9.01
# Episode 625: Reward = 108.84, Mean (100) = -8.15
# New best model saved with mean reward: -8.15
# Episode 626: Reward = 85.02, Mean (100) = -6.56
# New best model saved with mean reward: -6.56
# Episode 627: Reward = 138.68, Mean (100) = -4.88
# New best model saved with mean reward: -4.88
# Episode 628: Reward = -1.40, Mean (100) = -4.65
# New best model saved with mean reward: -4.65
# Episode 629: Reward = 106.95, Mean (100) = -2.95
# New best model saved with mean reward: -2.95
# Episode 630: Reward = 47.50, Mean (100) = -1.96
# New best model saved with mean reward: -1.96
# Episode 631: Reward = 98.97, Mean (100) = -0.56
# ...
# Episode 2729: Reward = 299.09, Mean (100) = 268.41
# Episode 2730: Reward = 303.91, Mean (100) = 268.88
# Episode 2731: Reward = 307.06, Mean (100) = 268.93
# Episode 2732: Reward = 144.52, Mean (100) = 267.50
# Episode 2733: Reward = 282.09, Mean (100) = 267.22
# Episode 2734: Reward = 310.59, Mean (100) = 268.48
# Episode 2735: Reward = 283.81, Mean (100) = 268.83
# Episode 2736: Reward = 292.49, Mean (100) = 268.72
# Episode 2737: Reward = 13.90, Mean (100) = 266.12
# Episode 2738: Reward = 248.33, Mean (100) = 266.06
# Episode 2739: Reward = 279.55, Mean (100) = 266.18
# Episode 2740: Reward = 293.04, Mean (100) = 266.46
# Episode 2741: Reward = 246.48, Mean (100) = 267.47
# Episode 2742: Reward = 304.82, Mean (100) = 267.43
# Episode 2743: Reward = 304.55, Mean (100) = 267.56
# Episode 2744: Reward = 275.39, Mean (100) = 267.45
# Episode 2745: Reward = 299.31, Mean (100) = 267.60
# Episode 2746: Reward = 284.89, Mean (100) = 267.51
# Episode 2747: Reward = 253.31, Mean (100) = 266.94
# Episode 2748: Reward = 274.58, Mean (100) = 266.72
# Episode 2749: Reward = 273.69, Mean (100) = 266.63
# Episode 2750: Reward = 275.16, Mean (100) = 266.41
# Episode 2751: Reward = 268.23, Mean (100) = 266.38
# Episode 2752: Reward = 285.79, Mean (100) = 266.53
# Episode 2753: Reward = 283.72, Mean (100) = 269.49
# Episode 2754: Reward = 273.54, Mean (100) = 269.33
# Episode 2755: Reward = 291.27, Mean (100) = 269.14
# Episode 2756: Reward = 296.19, Mean (100) = 269.46
# Episode 2757: Reward = 290.67, Mean (100) = 269.51
# Episode 2758: Reward = 274.90, Mean (100) = 269.20
# Episode 2759: Reward = 253.30, Mean (100) = 268.66
# Episode 2760: Reward = 74.66, Mean (100) = 266.80
# Episode 2761: Reward = 3.30, Mean (100) = 263.67
# Episode 2762: Reward = 152.18, Mean (100) = 262.37
# Episode 2763: Reward = 257.82, Mean (100) = 262.27
# Episode 2764: Reward = 287.72, Mean (100) = 262.22
# Episode 2765: Reward = 305.64, Mean (100) = 262.17
# Episode 2766: Reward = 271.87, Mean (100) = 262.20
# Episode 2767: Reward = 260.96, Mean (100) = 261.85
# Episode 2768: Reward = 303.73, Mean (100) = 262.26
# Episode 2769: Reward = 300.94, Mean (100) = 264.08
# Episode 2770: Reward = 320.87, Mean (100) = 264.27
# Episode 2771: Reward = 293.58, Mean (100) = 266.98
# Episode 2772: Reward = 287.01, Mean (100) = 267.23
# Episode 2773: Reward = 248.67, Mean (100) = 267.01
# Episode 2774: Reward = 292.79, Mean (100) = 267.21
# Episode 2775: Reward = 285.59, Mean (100) = 267.20
# Episode 2776: Reward = 284.57, Mean (100) = 266.99
# Episode 2777: Reward = 290.93, Mean (100) = 267.14
# Episode 2778: Reward = 248.55, Mean (100) = 266.94
# Episode 2779: Reward = 255.86, Mean (100) = 266.49
# Episode 2780: Reward = 14.88, Mean (100) = 263.99
# Episode 2781: Reward = 305.70, Mean (100) = 264.15
# Episode 2782: Reward = 257.82, Mean (100) = 264.01
# Episode 2783: Reward = 286.69, Mean (100) = 263.93
# Episode 2784: Reward = 325.68, Mean (100) = 264.59
# Episode 2785: Reward = 244.53, Mean (100) = 264.14
# Episode 2786: Reward = 293.22, Mean (100) = 264.29
# Episode 2787: Reward = 266.37, Mean (100) = 264.27
# Episode 2788: Reward = 264.20, Mean (100) = 263.83
# Episode 2789: Reward = 289.41, Mean (100) = 264.00
# Episode 2790: Reward = 293.58, Mean (100) = 263.98
# Episode 2791: Reward = 288.05, Mean (100) = 264.17
# Episode 2792: Reward = 290.84, Mean (100) = 264.34
# Episode 2793: Reward = 281.40, Mean (100) = 264.32
# Episode 2794: Reward = 291.69, Mean (100) = 264.43
# Episode 2795: Reward = 263.08, Mean (100) = 266.20
# Episode 2796: Reward = 292.37, Mean (100) = 266.21
# Episode 2797: Reward = 308.45, Mean (100) = 266.45
# Episode 2798: Reward = 266.57, Mean (100) = 266.09
# Episode 2799: Reward = 266.65, Mean (100) = 265.83
# Episode 2800: Reward = 290.39, Mean (100) = 266.00
# Episode 2801: Reward = 284.52, Mean (100) = 266.02
# Episode 2802: Reward = 248.27, Mean (100) = 268.38
# Episode 2803: Reward = -6.11, Mean (100) = 265.57
# Episode 2804: Reward = 278.18, Mean (100) = 265.64
# Episode 2805: Reward = 258.39, Mean (100) = 265.44
# Episode 2806: Reward = 291.48, Mean (100) = 265.77
# Episode 2807: Reward = 305.79, Mean (100) = 265.60
# Episode 2808: Reward = 312.40, Mean (100) = 265.81
# Episode 2809: Reward = 278.95, Mean (100) = 266.06
# Episode 2810: Reward = 277.77, Mean (100) = 266.31
# Episode 2811: Reward = 291.27, Mean (100) = 266.50
# Episode 2812: Reward = 270.50, Mean (100) = 266.55
# Episode 2813: Reward = 278.83, Mean (100) = 266.56
# Episode 2814: Reward = 308.57, Mean (100) = 266.73
# Episode 2815: Reward = 260.02, Mean (100) = 266.26
# Episode 2816: Reward = 292.13, Mean (100) = 266.07
# Episode 2817: Reward = 262.22, Mean (100) = 265.69
# Episode 2818: Reward = 275.37, Mean (100) = 266.91
# Episode 2819: Reward = 261.16, Mean (100) = 266.56
# Episode 2820: Reward = 304.22, Mean (100) = 266.67
# Episode 2821: Reward = 276.77, Mean (100) = 266.52
# Episode 2822: Reward = 282.52, Mean (100) = 266.72
# Episode 2823: Reward = 244.74, Mean (100) = 266.22
# Episode 2824: Reward = 274.88, Mean (100) = 266.44
# Episode 2825: Reward = 267.04, Mean (100) = 266.23
# Episode 2826: Reward = 259.96, Mean (100) = 265.85
# Episode 2827: Reward = 95.97, Mean (100) = 264.01
# Episode 2828: Reward = 303.73, Mean (100) = 264.16
# Episode 2829: Reward = 59.56, Mean (100) = 261.77
# Episode 2830: Reward = 286.51, Mean (100) = 261.60
# Episode 2831: Reward = 287.81, Mean (100) = 261.40
# Episode 2832: Reward = 310.26, Mean (100) = 263.06
# Episode 2833: Reward = 294.87, Mean (100) = 263.19
# Episode 2834: Reward = 261.78, Mean (100) = 262.70
# Episode 2835: Reward = 287.30, Mean (100) = 262.74
# Episode 2836: Reward = 286.24, Mean (100) = 262.67
# Episode 2837: Reward = 269.00, Mean (100) = 265.22
# Episode 2838: Reward = 317.36, Mean (100) = 265.91
# Episode 2839: Reward = 303.40, Mean (100) = 266.15
# Episode 2840: Reward = 302.17, Mean (100) = 266.24
# Episode 2841: Reward = 278.63, Mean (100) = 266.57
# Episode 2842: Reward = 303.76, Mean (100) = 266.55
# Episode 2843: Reward = 271.36, Mean (100) = 266.22
# Episode 2844: Reward = 270.45, Mean (100) = 266.17
# Episode 2845: Reward = 295.25, Mean (100) = 266.13
# Episode 2846: Reward = 303.17, Mean (100) = 266.32
# Episode 2847: Reward = 318.42, Mean (100) = 266.97
# Episode 2848: Reward = 246.76, Mean (100) = 266.69
# Episode 2849: Reward = 312.57, Mean (100) = 267.08
# Episode 2850: Reward = 133.75, Mean (100) = 265.66
# Episode 2851: Reward = 282.44, Mean (100) = 265.81
# Episode 2852: Reward = 275.23, Mean (100) = 265.70
# Episode 2853: Reward = 272.95, Mean (100) = 265.59
# Episode 2854: Reward = 253.28, Mean (100) = 265.39
# Episode 2855: Reward = 289.45, Mean (100) = 265.37
# Episode 2856: Reward = 309.99, Mean (100) = 265.51
# Episode 2857: Reward = 265.96, Mean (100) = 265.26
# Episode 2858: Reward = 274.14, Mean (100) = 265.25
# Episode 2859: Reward = 286.27, Mean (100) = 265.58
# Episode 2860: Reward = 290.54, Mean (100) = 267.74
# Episode 2861: Reward = 273.16, Mean (100) = 270.44
# Episode 2862: Reward = 281.49, Mean (100) = 271.73
# Episode 2863: Reward = 280.40, Mean (100) = 271.96
# Episode 2864: Reward = 284.48, Mean (100) = 271.93
# Episode 2865: Reward = 266.31, Mean (100) = 271.53
# Episode 2866: Reward = 274.52, Mean (100) = 271.56
# Episode 2867: Reward = 293.58, Mean (100) = 271.89
# Episode 2868: Reward = 307.55, Mean (100) = 271.93
# Episode 2869: Reward = 277.97, Mean (100) = 271.70
# Episode 2870: Reward = 318.83, Mean (100) = 271.68
# Episode 2871: Reward = 274.78, Mean (100) = 271.49
# Episode 2872: Reward = 274.45, Mean (100) = 271.36
# Episode 2873: Reward = 174.70, Mean (100) = 270.62
# Episode 2874: Reward = 281.02, Mean (100) = 270.50
# Episode 2875: Reward = 294.92, Mean (100) = 270.60
# Episode 2876: Reward = 275.19, Mean (100) = 270.50
# Episode 2877: Reward = 294.35, Mean (100) = 270.54
# Episode 2878: Reward = 304.84, Mean (100) = 271.10
# Episode 2879: Reward = 286.04, Mean (100) = 271.40
# Episode 2880: Reward = 266.80, Mean (100) = 273.92
# New best model saved with mean reward: 273.92
# Episode 2881: Reward = 291.22, Mean (100) = 273.78
# Episode 2882: Reward = 295.77, Mean (100) = 274.16
# New best model saved with mean reward: 274.16
# Episode 2883: Reward = 309.12, Mean (100) = 274.38
# New best model saved with mean reward: 274.38
# Episode 2884: Reward = 295.40, Mean (100) = 274.08
# Episode 2885: Reward = 293.69, Mean (100) = 274.57
# New best model saved with mean reward: 274.57
# Episode 2886: Reward = 268.12, Mean (100) = 274.32
# Episode 2887: Reward = 287.44, Mean (100) = 274.53
# Episode 2888: Reward = 265.07, Mean (100) = 274.54
# Episode 2889: Reward = 317.91, Mean (100) = 274.82
# New best model saved with mean reward: 274.82
# Episode 2890: Reward = 317.94, Mean (100) = 275.07
# New best model saved with mean reward: 275.07
# Episode 2891: Reward = 293.96, Mean (100) = 275.13
# New best model saved with mean reward: 275.13
# Episode 2892: Reward = 296.49, Mean (100) = 275.18
# New best model saved with mean reward: 275.18
# Episode 2893: Reward = 297.66, Mean (100) = 275.35
# New best model saved with mean reward: 275.35
# Episode 2894: Reward = 272.74, Mean (100) = 275.16
# Episode 2895: Reward = 182.47, Mean (100) = 274.35
# Episode 2896: Reward = 259.52, Mean (100) = 274.02
# Episode 2897: Reward = 278.30, Mean (100) = 273.72
# Episode 2898: Reward = 309.11, Mean (100) = 274.15
# Episode 2899: Reward = 304.00, Mean (100) = 274.52
# Episode 2900: Reward = 277.55, Mean (100) = 274.39
# Episode 2901: Reward = 317.89, Mean (100) = 274.72
# Episode 2902: Reward = 273.15, Mean (100) = 274.97
# Episode 2903: Reward = 313.69, Mean (100) = 278.17
# New best model saved with mean reward: 278.17
# Episode 2904: Reward = 274.72, Mean (100) = 278.14
# Episode 2905: Reward = 271.86, Mean (100) = 278.27
# New best model saved with mean reward: 278.27
# Episode 2906: Reward = 293.84, Mean (100) = 278.29
# New best model saved with mean reward: 278.29
# Episode 2907: Reward = 264.72, Mean (100) = 277.88
# Episode 2908: Reward = 300.29, Mean (100) = 277.76
# Episode 2909: Reward = 288.74, Mean (100) = 277.86
# Episode 2910: Reward = 272.16, Mean (100) = 277.80
# Episode 2911: Reward = 272.14, Mean (100) = 277.61
# Episode 2912: Reward = 280.16, Mean (100) = 277.71
# Episode 2913: Reward = 309.69, Mean (100) = 278.02
# Episode 2914: Reward = 316.66, Mean (100) = 278.10
# Episode 2915: Reward = 282.82, Mean (100) = 278.33
# New best model saved with mean reward: 278.33
# Episode 2916: Reward = 264.03, Mean (100) = 278.05
# Episode 2917: Reward = 291.75, Mean (100) = 278.34
# New best model saved with mean reward: 278.34
# Episode 2918: Reward = 6.65, Mean (100) = 275.65
# Episode 2919: Reward = 267.42, Mean (100) = 275.72
# Episode 2920: Reward = 309.41, Mean (100) = 275.77
# Episode 2921: Reward = 307.53, Mean (100) = 276.08
# Episode 2922: Reward = 267.29, Mean (100) = 275.92
# Episode 2923: Reward = 278.75, Mean (100) = 276.26
# Episode 2924: Reward = 275.54, Mean (100) = 276.27
# Episode 2925: Reward = 273.19, Mean (100) = 276.33
# Episode 2926: Reward = 289.98, Mean (100) = 276.63
# Episode 2927: Reward = 322.39, Mean (100) = 278.90
# New best model saved with mean reward: 278.90
# Episode 2928: Reward = 319.93, Mean (100) = 279.06
# New best model saved with mean reward: 279.06
# Episode 2929: Reward = 314.27, Mean (100) = 281.61
# New best model saved with mean reward: 281.61
# Episode 2930: Reward = 264.08, Mean (100) = 281.38
# Episode 2931: Reward = 276.83, Mean (100) = 281.27
# Episode 2932: Reward = 291.54, Mean (100) = 281.08
# Episode 2933: Reward = 281.67, Mean (100) = 280.95
# Episode 2934: Reward = 268.73, Mean (100) = 281.02
# Episode 2935: Reward = 300.44, Mean (100) = 281.15
# Episode 2936: Reward = 308.38, Mean (100) = 281.37
# Episode 2937: Reward = 273.66, Mean (100) = 281.42
# Episode 2938: Reward = 301.90, Mean (100) = 281.27
# Episode 2939: Reward = 272.05, Mean (100) = 280.95
# Episode 2940: Reward = 313.00, Mean (100) = 281.06
# Episode 2941: Reward = 202.34, Mean (100) = 280.30
# Episode 2942: Reward = 308.69, Mean (100) = 280.35
# Episode 2943: Reward = 308.11, Mean (100) = 280.72
# Episode 2944: Reward = 270.31, Mean (100) = 280.71
# Episode 2945: Reward = 295.64, Mean (100) = 280.72
# Episode 2946: Reward = 255.77, Mean (100) = 280.24
# Episode 2947: Reward = 270.60, Mean (100) = 279.77
# Episode 2948: Reward = 322.65, Mean (100) = 280.52
# Episode 2949: Reward = 290.91, Mean (100) = 280.31
# Episode 2950: Reward = 310.48, Mean (100) = 282.08
# New best model saved with mean reward: 282.08
# Episode 2951: Reward = 306.11, Mean (100) = 282.31
# New best model saved with mean reward: 282.31
# Episode 2952: Reward = 261.57, Mean (100) = 282.18
# Episode 2953: Reward = 285.14, Mean (100) = 282.30
# Episode 2954: Reward = 285.08, Mean (100) = 282.62
# New best model saved with mean reward: 282.62
# Episode 2955: Reward = 252.03, Mean (100) = 282.24
# Episode 2956: Reward = 287.29, Mean (100) = 282.01
# Episode 2957: Reward = 296.57, Mean (100) = 282.32
# Episode 2958: Reward = 262.27, Mean (100) = 282.20
# Episode 2959: Reward = 292.11, Mean (100) = 282.26
# Episode 2960: Reward = 271.29, Mean (100) = 282.07
# Episode 2961: Reward = 302.33, Mean (100) = 282.36
# Episode 2962: Reward = 269.78, Mean (100) = 282.24
# Episode 2963: Reward = 314.65, Mean (100) = 282.58
# Episode 2964: Reward = 303.56, Mean (100) = 282.78
# New best model saved with mean reward: 282.78
# Episode 2965: Reward = 19.17, Mean (100) = 280.30
# Episode 2966: Reward = 297.36, Mean (100) = 280.53
# Episode 2967: Reward = 270.33, Mean (100) = 280.30
# Episode 2968: Reward = 267.98, Mean (100) = 279.90
# Episode 2969: Reward = 286.11, Mean (100) = 279.99
# Episode 2970: Reward = 264.68, Mean (100) = 279.44
# Episode 2971: Reward = 291.62, Mean (100) = 279.61
# Episode 2972: Reward = 267.70, Mean (100) = 279.55
# Episode 2973: Reward = 322.36, Mean (100) = 281.02
# Episode 2974: Reward = 285.31, Mean (100) = 281.06
# Episode 2975: Reward = 270.66, Mean (100) = 280.82
# Episode 2976: Reward = 290.54, Mean (100) = 280.98
# Episode 2977: Reward = 269.84, Mean (100) = 280.73
# Episode 2978: Reward = 260.94, Mean (100) = 280.29
# Episode 2979: Reward = 279.87, Mean (100) = 280.23
# Episode 2980: Reward = 305.87, Mean (100) = 280.62
# Episode 2981: Reward = 263.18, Mean (100) = 280.34
# Episode 2982: Reward = 312.79, Mean (100) = 280.51
# Episode 2983: Reward = 274.73, Mean (100) = 280.17
# Episode 2984: Reward = 261.95, Mean (100) = 279.83
# Episode 2985: Reward = 262.00, Mean (100) = 279.51
# Episode 2986: Reward = 291.28, Mean (100) = 279.75
# Episode 2987: Reward = 276.89, Mean (100) = 279.64
# Episode 2988: Reward = 279.97, Mean (100) = 279.79
# Episode 2989: Reward = -5.01, Mean (100) = 276.56
# Episode 2990: Reward = 269.11, Mean (100) = 276.07
# Episode 2991: Reward = 278.76, Mean (100) = 275.92
# Episode 2992: Reward = 305.15, Mean (100) = 276.01
# Episode 2993: Reward = 324.66, Mean (100) = 276.28
# Episode 2994: Reward = 303.12, Mean (100) = 276.58
# Episode 2995: Reward = 259.29, Mean (100) = 277.35
# Episode 2996: Reward = 257.74, Mean (100) = 277.33
# Episode 2997: Reward = 308.17, Mean (100) = 277.63
# Episode 2998: Reward = 282.63, Mean (100) = 277.37
# Episode 2999: Reward = 288.42, Mean (100) = 277.21
# Episode 3000: Reward = 279.01, Mean (100) = 277.22
# Training completed. Final model saved.
#
# Evaluating best model...
# C:\Users\Oskar\AppData\Local\Temp\ipykernel_3524\365812944.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.actor_critic.load_state_dict(torch.load(path))
# Evaluation over 100 episodes:
# Average Reward: 281.88 ± 20.30
# Average Episode Length: 206.43
